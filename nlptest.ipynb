# %%
import pandas as pd
import numpy as np
import nltk 
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk import word_tokenize
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score
np.random.seed(500)

nltk.download('punkt')
nltk.download('wordnet')
nltk.download('averaged_perceptron_tagger')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/simonpichon/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/simonpichon/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/simonpichon/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/simonpichon/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
Corpus = pd.read_csv("/Users/simonpichon/Desktop/En cours/datamining/Kaggle_miage/Data/corpus.csv",encoding='latin-1')

# %%
# Step - a : Remove blank rows if any.
Corpus['text'].dropna(inplace=True)
# Step - b : Change all the text to lower case. This is required as python interprets 'dog' and 'DOG' differently
Corpus['text'] = [entry.lower() for entry in Corpus['text']]
# Step - c : Tokenization : In this each entry in the corpus will be broken into set of words
Corpus['text']= [word_tokenize(entry) for entry in Corpus['text']]
# Step - d : Remove Stop words, Non-Numeric and perfom Word Stemming/Lemmenting.
# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
tag_map = defaultdict(lambda : wn.NOUN)
tag_map['J'] = wn.ADJ
tag_map['V'] = wn.VERB
tag_map['R'] = wn.ADV
for index,entry in enumerate(Corpus['text']):
    # Declaring Empty List to store the words that follow the rules for this step
    Final_words = []
    # Initializing WordNetLemmatizer()
    word_Lemmatized = WordNetLemmatizer()
    # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
    for word, tag in pos_tag(entry):
        # Below condition is to check for Stop words and consider only alphabets
        if word not in stopwords.words('english') and word.isalpha():
            word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
            Final_words.append(word_Final)
    # The final processed set of words for each iteration will be stored in 'text_final'
    Corpus.loc[index,'text_final'] = str(Final_words)

# %%
print(Corpus)
# Out:
#                                                    text       label  \
# 0     [stuning, even, for, the, non-gamer, :, this, ...  __label__2
# 1     [the, best, soundtrack, ever, to, anything, .,...  __label__2
# 2     [amazing, !, :, this, soundtrack, is, my, favo...  __label__2
# 3     [excellent, soundtrack, :, i, truly, like, thi...  __label__2
# 4     [remember, ,, pull, your, jaw, off, the, floor...  __label__2
# 5     [an, absolute, masterpiece, :, i, am, quite, s...  __label__2
# 6     [buyer, beware, :, this, is, a, self-published...  __label__1
# 7     [glorious, story, :, i, loved, whisper, of, th...  __label__2
# 8     [a, five, star, book, :, i, just, finished, re...  __label__2
# 9     [whispers, of, the, wicked, saints, :, this, w...  __label__2
# 10    [the, worst, !, :, a, complete, waste, of, tim...  __label__1
# 11    [great, book, :, this, was, a, great, book, ,,...  __label__2
# 12    [great, read, :, i, thought, this, book, was, ...  __label__2
# 13    [oh, please, :, i, guess, you, have, to, be, a...  __label__1
# 14    [awful, beyond, belief, !, :, i, feel, i, have...  __label__1
# 15    [do, n't, try, to, fool, us, with, fake, revie...  __label__1
# 16    [a, romantic, zen, baseball, comedy, :, when, ...  __label__2
# 17    [fashionable, compression, stockings, !, :, af...  __label__2
# 18    [jobst, ultrasheer, thigh, high, :, excellent,...  __label__2
# 19    [sizes, recomended, in, the, size, chart, are,...  __label__1
# 20    [mens, ultrasheer, :, this, model, may, be, ok...  __label__1
# 21    [delicious, cookie, mix, :, i, thought, it, wa...  __label__2
# 22    [another, abysmal, digital, copy, :, rather, t...  __label__1
# 23    [a, fascinating, insight, into, the, life, of,...  __label__2
# 24    [i, liked, this, album, more, then, i, thought...  __label__2
# 25    [problem, with, charging, smaller, aaas, :, i,...  __label__1
# 26    [works, ,, but, not, as, advertised, :, i, bou...  __label__1
# 27    [disappointed, :, i, read, the, reviews, ,, ma...  __label__1
# 28    [oh, dear, :, i, was, excited, to, find, a, bo...  __label__1
# 29    [based, on, the, reviews, here, i, bought, one...  __label__2
# ...                                                 ...         ...
# 9970  [beware, :, the, product, does, give, the, sur...  __label__1
# 9971  [happy, i, only, wasted, money, for, 2, music,...  __label__1
# 9972  [oh, my, goodness, !, :, if, this, is, a, sing...  __label__1
# 9973  [the, dummy, ``, fats, '', is, hysterical, !, ...  __label__2
# 9974  [dummy, scared, the, be-jesus, out, of, me, :,...  __label__1
# 9975  [more, ham-o-rama, theatrics, from, sir, antho...  __label__1
# 9976  [take, the, knife, up, the, hill, and, rent, t...  __label__2
# 9977  [magic, ads, were, scary, !, :, though, the, m...  __label__2
# 9978  [deliciously, disturbing, ..., .highly, undere...  __label__2
# 9979  [magic, :, if, you, like, anthony, hopkins, ,,...  __label__2
# 9980  [magic, ,, on, blu, ray, ,, starrring, anthony...  __label__2
# 9981  [a, ventriloquists, nightmare, :, magic, is, a...  __label__2
# 9982  [great, movie, massacred, by, tape, quality, :...  __label__1
# 9983  [early, hopkins, story, still, sends, chills, ...  __label__2
# 9984  [the, only, dummy, is, the, writer, :, ``, mag...  __label__1
# 9985  [``, he, 's, no, dummy, ., ., ., ``, :, viewin...  __label__2
# 9986  [amazingly, suspenseful, psychological, thrill...  __label__2
# 9987  [a, truly, great, horror, movie, :, i, saw, th...  __label__2
# 9988  [frightening, movie, with, superb, acting, by,...  __label__2
# 9989  [classic, :, i, got, this, for, my, dad, ., it...  __label__2
# 9990  [psychological, thriller, !, :, this, movie, r...  __label__2
# 9991  [a, little, more, money, than, what, i, expect...  __label__2
# 9992  [``, the, silence, of, the, dummies, '', :, th...  __label__1
# 9993  [mauled, again, -, killing, bears, to, enrich,...  __label__1
# 9994  [sorry, jim, :, as, a, former, realtor, ,, mr....  __label__1
# 9995  [a, revelation, of, life, in, small, town, ame...  __label__2
# 9996  [great, biography, of, a, very, interesting, j...  __label__2
# 9997  [interesting, subject, ;, poor, presentation, ...  __label__1
# 9998  [do, n't, buy, :, the, box, looked, used, and,...  __label__1
# 9999  [beautiful, pen, and, fast, delivery, ., :, th...  __label__2
#
#                                              text_final
# 0     ['stun', 'even', 'sound', 'track', 'beautiful'...
# 1     ['best', 'soundtrack', 'ever', 'anything', 're...
# 2     ['amaze', 'soundtrack', 'favorite', 'music', '...
# 3     ['excellent', 'soundtrack', 'truly', 'like', '...
# 4     ['remember', 'pull', 'jaw', 'floor', 'hear', '...
# 5     ['absolute', 'masterpiece', 'quite', 'sure', '...
# 6     ['buyer', 'beware', 'book', 'want', 'know', 'r...
# 7     ['glorious', 'story', 'love', 'whisper', 'wick...
# 8     ['five', 'star', 'book', 'finish', 'read', 'wh...
# 9     ['whisper', 'wicked', 'saint', 'easy', 'read',...
# 10    ['bad', 'complete', 'waste', 'time', 'typograp...
# 11    ['great', 'book', 'great', 'book', 'could', 'p...
# 12    ['great', 'read', 'think', 'book', 'brilliant'...
# 13    ['oh', 'please', 'guess', 'romance', 'novel', ...
# 14    ['awful', 'beyond', 'belief', 'feel', 'write',...
# 15    ['try', 'fool', 'u', 'fake', 'review', 'glarin...
# 16    ['romantic', 'zen', 'baseball', 'comedy', 'hea...
# 17    ['fashionable', 'compression', 'stocking', 'dv...
# 18    ['jobst', 'ultrasheer', 'thigh', 'high', 'exce...
# 19    ['size', 'recomended', 'size', 'chart', 'real'...
# 20    ['men', 'ultrasheer', 'model', 'may', 'ok', 's...
# 21    ['delicious', 'cookie', 'mix', 'think', 'funny...
# 22    ['another', 'abysmal', 'digital', 'copy', 'rat...
# 23    ['fascinating', 'insight', 'life', 'modern', '...
# 24    ['like', 'album', 'thought', 'would', 'hear', ...
# 25    ['problem', 'charge', 'small', 'aaa', 'charger...
# 26    ['work', 'advertised', 'buy', 'one', 'instruct...
# 27    ['disappointed', 'read', 'review', 'make', 'pu...
# 28    ['oh', 'dear', 'excite', 'find', 'book', 'oste...
# 29    ['base', 'review', 'buy', 'one', 'glad', 'earl...
# ...                                                 ...
# 9970  ['beware', 'product', 'give', 'surround', 'sou...
# 9971  ['happy', 'waste', 'money', 'music', 'experien...
# 9972  ['oh', 'goodness', 'single', 'release', 'must'...
# 9973  ['dummy', 'fat', 'hysterical', 'really', 'say'...
# 9974  ['dummy', 'scar', 'oh', 'god', 'remember', 'se...
# 9975  ['theatrics', 'sir', 'anthony', 'whenever', 'a...
# 9976  ['take', 'knife', 'hill', 'rent', 'movie', 'fo...
# 9977  ['magic', 'ad', 'scary', 'though', 'movie', 'f...
# 9978  ['deliciously', 'disturb', 'underestimated', '...
# 9979  ['magic', 'like', 'anthony', 'hopkins', 'one',...
# 9980  ['magic', 'blu', 'ray', 'starrring', 'anthony'...
# 9981  ['ventriloquist', 'nightmare', 'magic', 'timel...
# 9982  ['great', 'movie', 'massacre', 'tape', 'qualit...
# 9983  ['early', 'hopkins', 'story', 'still', 'send',...
# 9984  ['dummy', 'writer', 'magic', 'pose', 'question...
# 9985  ['dummy', 'viewing', 'magic', 'first', 'become...
# 9986  ['amazingly', 'suspenseful', 'psychological', ...
# 9987  ['truly', 'great', 'horror', 'movie', 'saw', '...
# 9988  ['frighten', 'movie', 'superb', 'act', 'sir', ...
# 9989  ['classic', 'get', 'dad', 'super', 'creepy', '...
# 9990  ['psychological', 'thriller', 'movie', 'really...
# 9991  ['little', 'money', 'expect', 'spend', 'good',...
# 9992  ['silence', 'dummy', 'overall', 'real', 'hoot'...
# 9993  ['maul', 'kill', 'bear', 'enrich', 'jim', 'col...
# 9994  ['sorry', 'jim', 'former', 'realtor', 'cole', ...
# 9995  ['revelation', 'life', 'small', 'town', 'ameri...
# 9996  ['great', 'biography', 'interesting', 'journal...
# 9997  ['interest', 'subject', 'poor', 'presentation'...
# 9998  ['buy', 'box', 'look', 'use', 'obviously', 'ne...
# 9999  ['beautiful', 'pen', 'fast', 'delivery', 'pen'...
#
# [10000 rows x 3 columns]

# %%
Train_X, Test_X, Train_Y, Test_Y = model_selection.train_test_split(Corpus['text_final'],Corpus['label'],test_size=0.3)

# %%
Encoder = LabelEncoder()
Train_Y = Encoder.fit_transform(Train_Y)
Test_Y = Encoder.fit_transform(Test_Y)

# %%
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(Corpus['text_final'])
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)

# %%
print(Train_X_Tfidf)
print(Tfidf_vect.vocabulary_)
# Out:
#   (0, 4505)	0.3763188267807246
#   (0, 4504)	0.15031494427382475
#   (0, 3977)	0.35868777245753825
#   (0, 3891)	0.2515140235472667
#   (0, 3858)	0.2690675584422277
#   (0, 3745)	0.34695623926050195
#   (0, 3661)	0.2896999547088821
#   (0, 3564)	0.29449641491430995
#   (0, 2932)	0.229683025366997
#   (0, 1936)	0.13406125327954532
 1252, 'scar': 3843, 'life': 2578, 'death': 1093, 'ancient': 168, 'dragon': 1310, 'lose': 2646, 'drown': 1332, 'two': 4629, 'home': 2138, 'girlfriend': 1913, 'three': 4482, 'garden': 1876, 'god': 1930, 'sea': 3883, 'burn': 583, 'prayer': 3373, 'tower': 4555, 'radical': 3528, 'bring': 539, 'remember': 3661, 'pull': 3479, 'jaw': 2401, 'floor': 1756, 'know': 2480, 'single': 4025, 'song': 4111, 'tell': 4412, 'story': 4248, 'good': 1936, 'great': 1968, 'without': 4921, 'doubt': 1298, 'magical': 2688, 'wind': 4904, 'jewel': 2415, 'translation': 4575, 'perfect': 3227, 'ask': 258, 'pour': 3360, 'heart': 2071, 'paper': 3167, 'absolute': 6, 'quite': 3517, 'actually': 48, 'least': 2545, 'heard': 2069, 'whether': 4877, 'aware': 314, 'contribute': 937, 'greatly': 1969, 'mood': 2886, 'minute': 2846, 'whole': 4885, 'exact': 1552, 'count': 975, 'remarkable': 3659, 'assure': 270, 'forget': 1785, 'everything': 1541, 'listener': 2610, 'dance': 1066, 'slow': 4069, 'haunting': 2054, 'purely': 3490, 'beautifully': 380, 'compose': 876, 'fantastic': 1646, 'vocal': 4799, 'surely': 4334, 'buyer': 594, 'beware': 419, 'book': 480, 'want': 4819, 'paragraph': 3173, 'family': 1641, 'friend': 1826, 'perhaps': 3233, 'imagine': 2225, 'thing': 4465, 'spend': 4162, 'evening': 1532, 'piece': 3269, 'another': 187, 'definitely': 1122, 'bad': 330, 'enough': 1482, 'enter': 1485, 'kind': 2465, 'contest': 929, 'believe': 397, 'amazon': 152, 'sell': 3909, 'maybe': 2759, 'offer': 3060, 'grade': 1951, 'term': 4427, 'kill': 2462, 'anyway': 200, 'unless': 4682, 'send': 3911, 'someone': 4104, 'joke': 2429, 'far': 1648, 'glorious': 1922, 'love': 2655, 'wicked': 4888, 'saint': 3811, 'pleasantly': 3306, 'surprise': 4340, 'change': 694, 'romance': 3768, 'novel': 3025, 'world': 4942, 'rave': 3559, 'brilliant': 537, 'true': 4606, 'wonderful': 4930, 'typical': 4631, 'crime': 1012, 'becuase': 384, 'miss': 2854, 'warm': 4822, 'five': 1735, 'finish': 1716, 'fell': 1679, 'expect': 1584, 'average': 307, 'instead': 2314, 'find': 1712, 'think': 4466, 'predict': 3380, 'outcome': 3118, 'shock': 3977, 'descriptive': 1163, 'break': 520, 'julia': 2438, 'felt': 1682, 'reader': 3566, 'lover': 2659, 'let': 2566, 'cover': 986, 'fool': 1777, 'spectacular': 4157, 'easy': 1382, 'make': 2699, 'keep': 2453, 'reading': 3568, 'put': 3498, 'leave': 2547, 'follow': 1771, 'come': 830, 'soon': 4115, 'use': 4716, 'get': 1903, 'enjoyable': 1477, 'complete': 868, 'waste': 4837, ' ...

# %%
# fit the training dataset on the NB classifier
Naive = naive_bayes.MultinomialNB()
Naive.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_NB = Naive.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("Naive Bayes Accuracy Score -> ",accuracy_score(predictions_NB, Test_Y)*100)
# Out:
# Naive Bayes Accuracy Score ->  83.13333333333334

# %%
# Classifier - Algorithm - SVM
# fit the training dataset on the classifier
SVM = svm.SVC(C=1.0, kernel='linear', degree=3, gamma='auto')
SVM.fit(Train_X_Tfidf,Train_Y)
# predict the labels on validation dataset
predictions_SVM = SVM.predict(Test_X_Tfidf)
# Use accuracy_score function to get the accuracy
print("SVM Accuracy Score -> ",accuracy_score(predictions_SVM, Test_Y)*100)
# Out:
# SVM Accuracy Score ->  84.8
